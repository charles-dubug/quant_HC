# %%
import utils
import os

# %%
current_dir = os.getcwd()
predictions_file = os.path.join(current_dir, 'predictions.json')
stock_concept_map_file = os.path.join(current_dir, 'stock_concept_map.json')

# %%
top_stocks = utils.compute_stock_ratings(predictions_file, stock_concept_map_file)

# %%
print(top_stocks)
# Out:
# [('603310', 8.0), ('000517', 7.0), ('301043', 7.0), ('603041', 6.5), ('002319', 6.0), ('002790', 6.0), ('300727', 6.0), ('301161', 6.0), ('301300', 6.0), ('603281', 6.0), ('605318', 6.0), ('688668', 6.0), ('300891', 5.5), ('301032', 5.5), ('601100', 5.5), ('601128', 5.5), ('603218', 5.5), ('002810', 5.333333333333333), ('688386', 5.333333333333333), ('000545', 5.0), ('001226', 5.0), ('001268', 5.0), ('002043', 5.0), ('002142', 5.0), ('002211', 5.0), ('002283', 5.0), ('002337', 5.0), ('002459', 5.0), ('002674', 5.0), ('002779', 5.0), ('002798', 5.0), ('002839', 5.0), ('002936', 5.0), ('002961', 5.0), ('300093', 5.0), ('300126', 5.0), ('300163', 5.0), ('300475', 5.0), ('300718', 5.0), ('300821', 5.0), ('301176', 5.0), ('301251', 5.0), ('301332', 5.0), ('301446', 5.0), ('301533', 5.0), ('600599', 5.0), ('600908', 5.0), ('600926', 5.0), ('601009', 5.0), ('601187', 5.0), ('601229', 5.0), ('601233', 5.0), ('601577', 5.0), ('601665', 5.0), ('601825', 5.0), ('603002', 5.0), ('603016', 5.0), 
# ...

# %%
# Print results
print(f"Top {len(top_stocks)} stocks by concept rating:")
for i, (stock_code, rating) in enumerate(top_stocks, 1):
    print(f"{i}. Stock {stock_code}: Rating {rating:.2f}")
# Out:
# Top 500 stocks by concept rating:
# 1. Stock 603310: Rating 8.00
# 2. Stock 000517: Rating 7.00
# 3. Stock 301043: Rating 7.00
# 4. Stock 603041: Rating 6.50
# 5. Stock 002319: Rating 6.00
# 6. Stock 002790: Rating 6.00
# 7. Stock 300727: Rating 6.00
# 8. Stock 301161: Rating 6.00
# 9. Stock 301300: Rating 6.00
# 10. Stock 603281: Rating 6.00
# 11. Stock 605318: Rating 6.00
# 12. Stock 688668: Rating 6.00
# 13. Stock 300891: Rating 5.50
# 14. Stock 301032: Rating 5.50
# 15. Stock 601100: Rating 5.50
# 16. Stock 601128: Rating 5.50
# 17. Stock 603218: Rating 5.50
# 18. Stock 002810: Rating 5.33
# 19. Stock 688386: Rating 5.33
# 20. Stock 000545: Rating 5.00
# 21. Stock 001226: Rating 5.00
# 22. Stock 001268: Rating 5.00
# 23. Stock 002043: Rating 5.00
# 24. Stock 002142: Rating 5.00
# 25. Stock 002211: Rating 5.00
# 26. Stock 002283: Rating 5.00
# 27. Stock 002337: Rating 5.00
# 28. Stock 002459: Rating 5.00
# 29. Stock 002674: Rating 5.00
# 30. Stock 002779: Rating 5.00
# ...
