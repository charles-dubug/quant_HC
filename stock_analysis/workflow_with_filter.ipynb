# %%
import utils

# %%
utils.get_concept_capital_flow()
# Out:
# 1-day data loaded.
# 5-day data loaded.
# 10-day data loaded.
# Restructured data saved to ./data/2025-03-14/concept_capital_flow.json with 72 records

# %%
utils.concept_analysis(max_workers=3)
# Out:
# Processing 573 items in parallel...
# Processing boards: 100%|██████████| 573/573 [1:54:37<00:00, 12.00s/board, completed=573/573, percent=100.0%]
# All processing complete!

# %%
stocks_sorted = utils.compute_stock_ratings()
print(stocks_sorted)
print(len(stocks_sorted))
# Out:
# ['002842', '301141', '600193', '601579', '603198', '603589', '688077', '000612', '000802', '001201', '001202', '001228', '002203', '002378', '002715', '002905', '002942', '300575', '300833', '600233', '600857', '600987', '601058', '601061', '603151', '603310', '603363', '603599', '603993', '605003', '688251', '000831', '601600', '000860', '002716', '600711', '600727', '000426', '000506', '000545', '000596', '000622', '000799', '000995', '001366', '002237', '002567', '300761', '300779', '300891', '301190', '600381', '600389', '600559', '600809', '600872', '600961', '603369', '603399', '603477', '603919', '000688', '600259', '600331', '600988', '000975', '002136', '600301', '603072', '000816', '002458', '002840', '300224', '603389', '000060', '000737', '000553', '000571', '000603', '000892', '000965', '002155', '002488', '002661', '002738', '002739', '002759', '002895', '002966', '300528', '301035', '301116', '600078', '600136', '600490', '600612', '600696', '600916', '600975', '601020', '601022', '601128', '601339', '603489', '603611', '603900', '605151', '605296', '688021', '688255', '688455', '002167', '002186', '601069', '601212', '000758', '002714', '600197', '600199', '600750', '600111', '000655', '000751', '000876', '000878', '001317', '002120', '002304', '003017', '300240', '300426', '600531', '600547', '600787', '603045', '603103', '603391', '603609', '603979', '000960', '002145', '605376', '600392', '000629', '601899', '600010', '300340', '000408', '000501', '000534', '000568', '000697', '000702', '000713', '000718', '000755', '000869', '000902', '000962', '000983', '001316', '001330', '001337', '002114', '002124', '002134', '002199', '002234', '002311', '002442', '002548', '002721', '002731', '002940', '002978', '300111', '300452', '300505', '300618', '300797', '300835', '300856', '300967', '301000', '301008', '301030', '301130', '301273', '301289', '301323', '301509', '600088', '600121', '600173', '600265', '600295', '600350', '600362', '600365', '600367', '600382', '600391', '600399', '600470', '600486', '600489', '600655', '600702', '600732', '600824', '600971', '600977', '601001', '601666', '601699', '601958', '603076', '603505', '603558', '603587', '603682', '603826', '603983', '605086', '605116', '605259', '605507', '688028', '688215', '688239', '688510', '688571', '688700', '600459', '600456', '000895', '000738', '300945', '600372', '600497', '600693', '600980', '002907', '002982', '301118', '600184', '600519', '600596', '600959', '600549', '688456', '000978', '002540', '002588', '002646', '002664', '002742', '002746', '002943', '003003', '300631', '300896', '301052', '600052', '600153', '600366', '600779', '601169', '601595', '601688', '603178', '688189', '600141', '000546', '000762', '600316', '600893', '000031', '000048', '000525', '000582', '000858', '000930', '000933', '002225', '002800', '002891', '002918', '003042', '300013', '300211', '300385', '300498', '300695', '300771', '300860', '300873', '300876', '300894', '300901', '301071', '301235', '301413', '301419', '301520', '600188', '600338', '600567', '600714', '601101', '601163', '601599', '603117', '603267', '603299', '603836', '605599', '688386', '688523', '000768', '000970', '688122', '000912', '002240', '002926', '300027', '300402', '300555', '300775', '300871', '600066', '600119', '600698', '603701', '605555', '688005', '000529', '300748', '300792', '601168', '000830', '300034', '000756', '000017', '000630', '000833', '000927', '002052', '002125', '002297', '002342', '002345', '002520', '002538', '002651', '002698', '002760', '002779', '003016', '300069', '300258', '300363', '300583', '300584', '300696', '300816', '300918', '300970', '301021', '301032', '301220', '301226', '301246', '301258', '301277', '301358', '301368', '301515', '302132', '600026', '600058', '600059', '600073', '600219', '600258', '600298', '600448', '600622', '600685', '600755', '600760', '600778', '600792', '600794', '600866', '600936', '601088', '601116', '601188', '603081', ...
# 5002

# %%
top_stocks = utils.get_selected_stock_capital_flow(stock_codes=stocks_sorted, filter=100)
# Out:
# Processing stocks: 100%|██████████| 100/100 [05:16<00:00,  3.16s/stock, completed=100/100, percent=100.0%]

# %%
utils.get_selected_stock_k(top_stocks)
# Out:
# Processing stocks: 100%|██████████| 100/100 [00:51<00:00,  1.93stock/s, completed=100/100, percent=100.0%]

# %%
utils.stock_analysis(max_workers=3)
# Out:
# Processing 100 items in parallel...
# Processing stocks: 100%|██████████| 100/100 [18:50<00:00, 11.30s/stock, completed=100/100, percent=100.0%]
# Sorted 100 predictions by score (highest to lowest)
# Saved to: data/2025-03-12/stock_predictions_sorted.json
# All processing complete!

# %%
utils.order_analysis(max_workers=3, top_n=50)
# Out:
# Processing 50 top stocks for further analysis...
# Processing top stocks: 100%|██████████| 50/50 [17:43<00:00, 21.27s/stock, completed=50/50, percent=100.0%]
# Top stocks analysis complete!
